# %% [markdown]
# In this tutorial we will ingest data and store it in Snowflake using snowpark. We will cover the following topics:
#
# 1. Getting started with Snowpark
# 2. Setting Up Snowflake for Our Use
# 3. Ingesting BTC data from Binance API
# 4. Loading the data using Snowpark into Snowflake views
#
#
# ## 1. Getting Started with Snowflake
#
# Follow this [Link](https://docs.snowflake.com/en/developer-guide/snowpark/python/setup) to set up Snowpark in local environment.

# %%
from snowflake.snowpark import Session
from binance.client import Client
import pandas as pd
import datetime

# %% [markdown]
# To connect and run snowflake objects we first need to create a snowflake session.

# %%
account = "myccount"
user = "jdoe-test"
password = "******"
warehouse = "my-test_wh"
database = "my_test_db"
schema = "my_schema"
